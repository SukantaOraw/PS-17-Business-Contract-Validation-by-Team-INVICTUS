# %%
# !kaggle datasets download -d bahushruth/legalclausedataset -p /content

# %%
# !unzip -j /content/legalclausedataset.zip -d /content/Data_sets

# %%
import pandas as pd
import glob
import re
import spacy
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
import joblib
import matplotlib.pyplot as plt

# %%
# # Specify the directory containing CSV files (replace with your actual path)
# data_dir = "/content/Data_sets/"  # Update with your directory path

# # Create an empty list to store all dataframes
# all_paragraphs = []
# all_classes = []

# # Get a list of all CSV files using glob (more efficient for large folders)
# csv_files = glob.glob(data_dir + "*.csv")

# # Iterate through each CSV file
# for file in csv_files:
#     try:
#         # Read the CSV file into a Pandas DataFrame
#         df = pd.read_csv(file)

#         # Extract specific columns (modify column names if needed)
#         paragraphs = df['clause_text'].tolist()
#         classes = df['clause_type'].tolist()

#         # Append extracted data to the respective lists
#         all_paragraphs.extend(paragraphs)
#         all_classes.extend(classes)

#     except FileNotFoundError:
#         print(f"Error: File '{file}' not found. Skipping...")

#     except pd.errors.ParserError as e:
#         print(f"Error parsing '{file}': {e}. Skipping...")

# # Create a single DataFrame with all collected data
# df = pd.DataFrame({'clause_text': all_paragraphs, 'clause_type': all_classes})

# print("All CSV files processed successfully!")
# Out:
# All CSV files processed successfully!

# %%
df = pd.read_csv('Contract_Clauses.csv')

# %%
df = df.iloc[:, 1:]

# %%
df
# Out:
#                                               clause_text    clause_type
# 0       Distributions. Distributions shall be made to ...  distributions
# 1       Distributions. The Trustee, as of the First Se...  distributions
# 2       Distributions. Distributions shall be made to ...  distributions
# 3       Distributions. (a) On each Distribution Date, ...  distributions
# 4       Distributions. (a) The Trust Securities repres...  distributions
# ...                                                   ...            ...
# 150876  Term. The effective date of this agreement (th...           term
# 150877  Term. The Company shall have perpetual existence.           term
# 150878  Term. This Sublease will be for a term beginni...           term
# 150879  Term. This Agreement shall commence on the dat...           term
# 150880  Term. The term of this MOU shall commence on t...           term
#
# [150881 rows x 2 columns]

# %%
unique_types = df['clause_type'].unique()

print(unique_types)
# Out:
# ['distributions' 'release' 'enforcement' 'reports'
#  'entire-agreement-amendment' 'parties-in-interest' 'employees'
#  'base-salary' 'payment' 'governing-law-jurisdiction'
#  'termination-of-agreement' 'preamble' 'expenses' 'financial-information'
#  'tax-withholding' 'indemnity' 'construction' 'reimbursement' 'security'
#  'scope' 'redemption' 'termination-for-cause' 'grant-of-option'
#  'closing-date' 'merger' 'organization-and-qualification' 'appointment'
#  'force-majeure' 'therefore' 'exercise-of-option' 'consents'
#  'intellectual-property-rights' 'r-e-c-i-t-a-l-s' 'fractional-shares'
#  'withholding' 'third-party-beneficiaries' 'grant-of-security-interest'
#  'resignation' 'definition' 'choice-of-law' 'limited_liability'
#  'notices-etc' 'parking' 'services' 'withholding-taxes'
#  'change-in-control' 'bankruptcy' 'integration' 'waiver'
#  'application-of-proceeds' 'condemnation' 'interpretation' 'amendment'
#  'other' 'utilities' 'no-conflicts' 'organization-and-good-standing'
#  'representations-warranties-and-covenants' 'notice' 'security-interest'
#  'payment-of-expenses' 'judgments' 'entire-agreement'
#  'compliance-with-law' 'no-solicitation' 'certain-defined-terms'
#  'maintenance-of-office-or-agency' 'investment-company' 'conditions'
#  'binding-effect' 'officers-certificate' 'fees-and-expenses' 'vesting'
#  'costs-and-expenses' 'environmental-matters' 'exclusivity'
#  'enforceability' 'compensation-and-benefits' 'specific-performance'
#  'defined-terms' 'legal-proceedings' 'full-disclosure' 'ownership' 'taxes'
#  'conditions-precedent' 'meetings' 'relationship-of-the-parties'
#  'termination-without-cause' 'amendments-waivers' 'indemnification'
#  'permits' 'liabilities' 'fees' 'records' 'dispute-resolution' 'interest'
#  'remedies-cumulative' 'letters-of-credit' 'stock-options'
#  'conflict-of-interest' 'termination' 'no-waiver' 'fees_royalties'
#  'agreements' 'generally' 'position-and-duties' 'effectiveness'
#  'further-assurances' 'terms' 'warranty' 'miscellaneous'
#  'access-to-information' 'financial-statements' 'procedure' 'liability'
#  'support' 'non-disparagement' 'witnesseth-that' 'access'
#  'title-to-assets' 'seniority' 'non-solicitation' 'dividends'
#  'restrictive-covenants' 'certificates' 'marketing' 'usa-patriot-act'
#  'increased-costs' 'time-of-essence' 'execution'
#  'submission-to-jurisdiction' 'conditions-to-effectiveness'
#  'representations' 'public-announcements' 'notice-of-redemption'
#  'payment-of-obligations' 'other-benefits' 'limitations'
#  'payment-of-taxes' 'purpose' 'default' 'insolvency'
#  'standard-terms-and-conditions-of-trust' 'reliance' 'duties'
#  'representations-and-warranties' 'indebtedness' 'restricted-payments'
#  'costs' 'consideration' 'covenants-of-the-company' 'term-of-employment'
#  'voting' 'use-of-proceeds' 'insurance' 'jurisdiction'
#  'no-third-party-beneficiaries' 'parties' 'severability-of-provisions'
#  'successors' 'successors-and-assigns' 'remedies' 'accounting-terms'
#  'trustee-may-file-proofs-of-claim' 'definitions-and-interpretation'
#  'performance' 'brokerage' 'other-agreements' 'general-provisions'
#  'no-material-adverse-change' 'bonus' 'assignability' 'voting-rights'
#  'background' 'amendment-waiver' 'material-contracts' 'complete-agreement'
#  'employee-benefit-plans' 'transfer' 'non-discrimination'
#  'management-rights' 'bereavement-leave'
#  'indemnification-and-contribution' 'collateral' 'title' 'approvals'
#  'amendments-and-waivers' 'auto_renewal' 'modifications' 'survival'
#  'good-reason' 'compliance-certificate' 'descriptive-headings' 'name'
#  'vacation' 'effect-of-termination' 'acceleration' 'other-remedies'
#  'no-violation' 'headings' 'corporate-existence' 'event-of-default'
#  'purchase-and-sale' 'notice-of-defaults' 'confidentiality'
#  'representations-and-warranties-of-seller' 'death'
#  'intellectual-property' 'licenses' 'reporting-requirements' 'the-closing'
#  'term-and-termination' 'guarantee' 'definitions'
#  'reimbursement-of-expenses' 'defaults' 'disclaimer'
#  'independent-contractor' 'delivery' 'liens' 'counterparts'
#  'security-deposit' 'optional_renewal' 'disclosure' 'capitalized-terms'
#  'method-of-payment' 'recitals' 'registration' 'environmental-laws'
#  'powers' 'assignment' 'authority' 'amendments-etc' 'delegation-of-duties'
#  'compliance-with-laws' 'now-therefore' 'salary' 'introduction'
#  'execution-in-counterparts' 'modification-and-waiver' 'no-default'
#  'amendment-and-waiver' 'dissolution' 'rent' 'publicity' 'labor-matters'
#  'reporting' 'right-of-setoff' 'bank-accounts' 'solvency' 'payments'
#  'no-assignment' 'registration-procedures' 'compliance' 'recognition'
#  'documents' 'capitalization' 'person' 'the-merger' 'modification'
#  'representations-and-warranties-of-the-company' 'closing' 'currency'
#  'effect-of-headings' 'sick-leave' 'w-i-t-n-e-s-s-e-t-h-whereas'
#  'subrogation' 'maintenance-of-insurance' 'undertaking-for-costs'
#  'duration-of-agreement' 'conduct-of-business' 'section-headings'
#  'compensation' 'real-property' 'loans' 'governing-law'
#  'registration-rights' 'benefits' 'reinstatement' 'waiver-of-jury-trial'
#  'notification' 'participations' 'arbitration' 'time'
#  'absence-of-certain-changes-or-events' 'power-of-attorney'
#  'entire-agreement-amendments' 'contracts' 'effective-date'
#  'negative-covenants' 'defaults-and-remedies' 'notice-of-default'
#  'limitation-of-liability' 'witnesseth' 'guaranty' 'change-of-control'
#  'notices' 'listing' 'legend' 'duration-and-termination'
#  'in-witness-whereof' 'affirmative-covenants' 'cooperation'
#  'additional-documents' 'cancellation' 'exceptions'
#  'survival-of-representations-and-warranties' 'erisa' 'whereas'
#  'consents-and-approvals' 'severability' 'officers'
#  'confidential-information' 'governing-law-and-jurisdiction' 'amendments'
#  'adjustments' 'management' 'financial-covenants' 'payment-terms'
#  'waivers' 'indemnification-by-the-company' 'organization'
#  'persons-deemed-owners' 'warranties' 'partial-invalidity' 'litigation'
#  'standard-of-care' 'information' 'subsidiaries' 'investments'
#  'tax-returns' 'captions' 'term-of-agreement' 'cause'
#  'special-terms-and-conditions-of-trust' 'time-of-the-essence' 'use'
#  'investment-company-act' 'set-off' 'restrictions-on-transfer' 'general'
#  'proprietary_rights' 'illegality' 'additional-agreements' 'disputes'
#  'limitation-on-liability' 'books-and-records' 'brokers' 'validity'
#  'duration' 'employment' 'termination-of-employment' 'exhibits'
#  'subordination' 'inspection' 'transfers' 'fiscal-year'
#  'consent-to-jurisdiction' 'tax-matters' 'disability' 'non-competition'
#  'rules-of-construction' 'waiver-of-past-defaults' 'applicable-law'
#  'relationship-of-parties' 'events-of-default' 'certain-definitions'
#  'authorization' 'grievance-procedure' 'restrictions' 'other-provisions'
#  'transactions-with-affiliates' 'holidays' 'exclusions' 'agreement'
#  'no-strict-construction' 'absence-of-certain-changes' 'legends'
#  'covenants' 'registration-expenses' 'miscellaneous-provisions'
#  'attorneys-fees' 'notice-of-termination' 'contribution' 'purchase-price'
#  'financing' 'obligations-absolute' 'employee-benefits'
#  'injunctive-relief' 'maintenance-of-properties' 'no-conflict' 'severance'
#  'power-and-authority' 'assignments' 'term']

# %%
num_unique_types = df['clause_type'].nunique()

print(f"Number of unique clause types: {num_unique_types}")
# Out:
# Number of unique clause types: 395

# %%
unique_types_counts = df['clause_type'].value_counts()

unique_types_counts.plot(kind='bar', color='skyblue')

plt.xlabel('Clause Type')
plt.ylabel('Count')
plt.title('Distribution of Clause Types')

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Cleaning**

# %%
import nltk
from nltk.corpus import stopwords
import spacy

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sukan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.1/12.8 MB 1.1 MB/s eta 0:00:12
#       --------------------------------------- 0.2/12.8 MB 3.0 MB/s eta 0:00:05
#      -- ------------------------------------- 0.8/12.8 MB 5.6 MB/s eta 0:00:03
#      --- ------------------------------------ 1.0/12.8 MB 5.3 MB/s eta 0:00:03
#      --- ------------------------------------ 1.2/12.8 MB 5.0 MB/s eta 0:00:03
#      --- ------------------------------------ 1.2/12.8 MB 5.0 MB/s eta 0:00:03
#      --- ------------------------------------ 1.2/12.8 MB 5.0 MB/s eta 0:00:03
#      ---- ----------------------------------- 1.4/12.8 MB 3.7 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.4/12.8 MB 3.7 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.8/12.8 MB 3.8 MB/s eta 0:00:03
#      ------ --------------------------------- 2.0/12.8 MB 3.8 MB/s eta 0:00:03
#      ------ --------------------------------- 2.2/12.8 MB 3.8 MB/s eta 0:00:03
#      ------- -------------------------------- 2.4/12.8 MB 3.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.5/12.8 MB 3.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.7/12.8 MB 3.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.7/12.8 MB 3.9 MB/s eta 0:00:03
#      -------- ------------------------------- 2.7/12.8 MB 3.9 MB/s eta 0:00:03
#      --------- ------------------------------ 2.9/12.8 MB 3.5 MB/s eta 0:00:03
#      --------- ------------------------------ 3.2/12.8 MB 3.6 MB/s eta 0:00:03
#      ---------- ----------------------------- 3.4/12.8 MB 3.6 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.6/12.8 MB 3.6 MB/s eta 0:00:03
#      ----------- ---------------------------- 3.8/12.8 MB 3.6 MB/s eta 0:00:03
#      ------------ --------------------------- 3.9/12.8 MB 3.6 MB/s eta 0:00:03
#      ------------ --------------------------- 4.1/12.8 MB 3.7 MB/s eta 0:00:03
#      ------------- -------------------------- 4.3/12.8 MB 3.7 MB/s eta 0:00:03
#      -------------- ------------------------- 4.5/12.8 MB 3.7 MB/s eta 0:00:03
#      -------------- ------------------------- 4.7/12.8 MB 3.7 MB/s eta 0:00:03
#      --------------- ------------------------ 4.8/12.8 MB 3.7 MB/s eta 0:00:03
#      --------------- ------------------------ 5.0/12.8 MB 3.7 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.2/12.8 MB 3.7 MB/s eta 0:00:03
#      ---------------- ----------------------- 5.4/12.8 MB 3.7 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.6/12.8 MB 3.7 MB/s eta 0:00:02
#      ------------------ --------------------- 5.8/12.8 MB 3.7 MB/s eta 0:00:02
#      ------------------ --------------------- 5.9/12.8 MB 3.8 MB/s eta 0:00:02
#      ------------------- -------------------- 6.1/12.8 MB 3.8 MB/s eta 0:00:02
#      ------------------- -------------------- 6.3/12.8 MB 3.7 MB/s eta 0:00:02
#      -------------------- ------------------- 6.5/12.8 MB 3.7 MB/s eta 0:00:02
#      -------------------- ------------------- 6.7/12.8 MB 3.7 MB/s eta 0:00:02
#      --------------------- ------------------ 6.9/12.8 MB 3.8 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.0/12.8 MB 3.8 MB/s eta 0:00:02
#      ---------------------- ----------------- 7.2/12.8 MB 3.8 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.4/12.8 MB 3.8 MB/s eta 0:00:02
#      ----------------------- ---------------- 7.6/12.8 MB 3.8 MB/s eta 0:00:02
#      ------------------------ --------------- 7.8/12.8 MB 3.8 MB/s eta 0:00:02
#      ------------------------ --------------- 8.0/12.8 MB 3.8 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 3.8 MB/s eta 0:00:02
#      ------------------------- -------------- 8.1/12.8 MB 3.8 MB/s eta 0:00:02
#      -------------------------- ------------- 8.5/12.8 MB 3.8 MB/s eta 0:00:02
#      --------------------------- ------------ 8.7/12.8 MB 3.8 MB/s eta 0:00:02
#      --------------------------- ------------ 8.9/12.8 MB 3.8 MB/s eta 0:00:02
#      ---------------------------- ----------- 9.1/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.2/12.8 MB 3.8 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.4/12.8 MB 3.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.6/12.8 MB 3.8 MB/s eta 0:00:01
#      ------------------------------ --------- 9.8/12.8 MB 3.8 MB/s eta 0:00:01
#      ------------------------------- -------- 10.0/12.8 MB 3.8 MB/s eta 0:00:01
#      ------------------------------- -------- 10.2/12.8 MB 3.8 MB/s eta 0:00:01
#      -------------------------------- ------- 10.4/12.8 MB 3.9 MB/s eta 0:00:01
#      -------------------------------- ------- 10.5/12.8 MB 3.9 MB/s eta 0:00:01
#      --------------------------------- ------ 10.7/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 10.9/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 11.1/12.8 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.3/12.8 MB 3.7 MB/s eta 0:00:01
#      ----------------------------------- ---- 11.4/12.8 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------ --- 11.6/12.8 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 3.9 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 3.8 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 3.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.4)
# Requirement already satisfied: jinja2 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sukan\appdata\roaming\python\python312\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\sukan\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def clean_text(text):

    # Lowercase
    text = text.lower()

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text)

    # Handle common abbreviations (optional, modify as needed)
    text = re.sub(r"(§ )|(section )", "section ", text)
    text = re.sub(r"(para )|(paragraph )", "paragraph ", text)

    # Remove stop words
    text = " ".join([word for word in text.split() if word not in stop_words])

    # Lemmatization
    doc = nlp(text)
    text = " ".join([token.lemma_ for token in doc])

    return text

# %%
df["clause_text"] = df["clause_text"].apply(clean_text)

# %%
X_train, X_test, y_train, y_test = train_test_split(df['clause_text'], df['clause_type'], test_size=0.2, random_state=42)

# %%
le = LabelEncoder()

# %%
vectorizer = TfidfVectorizer(max_features=3000)
X_train_features = vectorizer.fit_transform(X_train)
X_test_features = vectorizer.transform(X_test)

# %% [markdown]
# Ensemble Method Start

# %%
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression

# %%
# Define different classifiers
clf1 = MLPClassifier(hidden_layer_sizes=(50, 50, 50), activation='relu', max_iter=500, solver='adam')
clf2 = LogisticRegression(max_iter=500)
clf3 = SVC(kernel='linear')

# %%
# Create an ensemble of classifiers
ensemble = VotingClassifier(estimators=[('mlp', clf1), ('lr', clf2), ('svc', clf3)], voting='hard')

# %%
# Fit the ensemble to the training data
ensemble.fit(X_train_features, y_train)
# Out:
# VotingClassifier(estimators=[('mlp',
#                               MLPClassifier(hidden_layer_sizes=(50, 50, 50),
#                                             max_iter=500)),
#                              ('lr', LogisticRegression(max_iter=500)),
#                              ('svc', SVC(kernel='linear'))])

# %%
# Make predictions and evaluate
y_pred = ensemble.predict(X_test_features)
accuracy = accuracy_score(y_test, y_pred)
print(f"Ensemble Accuracy: {accuracy:.4f}")
# Out:
# Ensemble Accuracy: 0.7964

# %%
import joblib

# %%
joblib.dump(vectorizer, 'ensemble_model_tfidf_vectorizer.pkl')
# Out:
# ['ensemble_model_tfidf_vectorizer.pkl']

# %%
joblib.dump(ensemble, 'ensemble_model.pkl')
print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
loaded_model = joblib.load('ensemble_model.pkl')
loaded_vectorizer = joblib.load('ensemble_model_tfidf_vectorizer.pkl')

# %%
# Example paragraph to test
paragraph_to_test = """

The Parties agree to the following terms and conditions:

"""

# Clean the paragraph
paragraph_to_test_cleaned = clean_text(paragraph_to_test)

# Get para vectors for the paragraph
paragraph_features = loaded_vectorizer.transform([paragraph_to_test_cleaned])

# %%
predicted_clause_type = loaded_model.predict(paragraph_features)
predicted_clause_type
# Out:
# array(['conditions'], dtype=object)

# %% [markdown]
# Ensemble Method End

# %%
# import seaborn as sns

# %%
# # Heatmap with color gradient
# sns.heatmap(cm, annot=True, cmap="YlGnBu", fmt="d")

# # Labels for axes and title
# plt.xlabel("Predicted Clause Type")
# plt.ylabel("True Clause Type")
# plt.title("Confusion Matrix")

# # Display the plot
# plt.show()
